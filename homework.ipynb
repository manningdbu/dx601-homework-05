# %% [markdown]
# # DX 601 Week 5 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will practice working random variables and estimating their parameters.
#
# The focus on these problems is on your understanding of the math, not the programming.
# Some of the data sets will be small enough that you can look at the data and calculate the answer in your head.
# That is acceptable, though we encourage you to also think about how to write code to perform the same calculation for you.
# We will work with larger data sets and provide more code examples for you as this class progress.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to these GitHub repositories of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx500-examples
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install scikit.learn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit.learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit.learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit.learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit.learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit.learn) (3.6.0)

# %%
import math
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1
#
# The variable `q1` below has data for a probability distribution.
# The keys of `q1` are supposed to be ratings from 1 to 5 and the values are supposed to be the probabilities of each rating.
# However, the data for the rating of 5 is missing.
# Set `p1` to be the probability of rating 5 assuming that the probabilities for 1 to 4 are correct.

# %%
q1 = {1: 0.32, 2: 0.22, 3: 0.12, 4: 0.1}

# %%
# YOUR CHANGES HERE
# all probabilities should add up to 1
p1 = (1 - sum(q1.values()))

# %% [markdown]
# Check the value of `p1`.

# %%
p1
# Out:
# 0.24

# %% [markdown]
# ### Problem 2
#
# The variable `q2` below has data for a probability distribution.
# The keys of `q2` are integer ratings from 1 to 5 and the values are the probabilities of each rating.
# Set `p2` to the average rating based on `q2`.

# %%
q2 = {1 : 0.11, 2: 0.18, 3: 0.35, 4: 0.24, 5: 0.12}

# %%
# YOUR CHANGES HERE
# average rating = expected value
# each value needs to be multiplied by its probability so 1 * 0.11, 2 * 0.18 etc.
p2 = sum(rating * prob for rating, prob in q2.items())

# %% [markdown]
# Check the value of `p2`.

# %%
p2
# Out:
# 3.0799999999999996

# %% [markdown]
# ### Problem 3
#
# Set `p3` to the sample probability that the rated flavor is at least 3 in `q3`.

# %%
# DO NOT CHANGE

q3 = pd.read_csv("/mango-tiny.tsv", sep="\t")
q3
# Out:
#    green_rating  yellow_rating  softness  wrinkles  estimated_flavor  \
# 0             1              5         4         0                 4
# 1             1              5         5         1                 5
# 2             2              4         3         1                 3
# 3             3              3         2         0                 2
# 4             5              1         1         1                 1
# 5             4              2         1         1                 1
# 6             5              1         1         1                 2
# 7             3              3         2         1                 2
#
#    estimated_sweetness  rated_flavor
# 0                    4             5
# 1                    5             1
# 2                    3             3
# 3                    1             2
# 4                    1             1
# 5                    1             1
# 6                    1             1
# 7                    2             2

# %%
# YOUR CHANGES HERE
# I was able to do this one in my head as the dataset is small. I needed to look up the
# python formula for this to run on a bigger dataset
p3 = 2/8

# %% [markdown]
# Check the value of `p3`.

# %%
p3
# Out:
# 0.25

# %% [markdown]
# ### Problem 4
#
# Set `p4` to the probability of sampling the exact sequence of values in `q4` assuming that it is a Boolean random variable which is True with probability 0.9.

# %%
# DO NOT CHANGE
# every true = 0.9 so every false = 0.1
q4 = [False, False, True, True, True, True, True, True, True, False]

# %%
# YOUR CHANGES HERE
p4 = (0.9 ** 7) * (0.1 ** 3)

# %%
p4
# Out:
# 0.0004782969000000002

# %%
ch4 = (0.01 * 1)* (0.99 * 99)
ch4
# Out:
# 0.9801000000000001

# %% [markdown]
# ### Problem 5
#
# `q5` was populated with samples of a Boolean random variable with an unknown probability.
# Set `p5` to the best estimate for that probability based on the sample in `q5`.

# %%
# DO NOT CHANGE

q5 = [ True,  True,  True,  True, False,  True, False,  True,  True,
        True,  True,  True,  True,  True,  True,  True,  True,  True,
        True,  True]

# %%
# YOUR CHANGES HERE

p5 = sum(q5)/len(q5)

# %%
p5
# Out:
# 0.9

# %% [markdown]
# ### Problem 6
#
# The variable `q6` has a probability where the keys are different events and the values are the probabilities of those events.
# Set `p6` to be the entropy of that probability distribution using base 2 for the logarithm.

# %%
q6 = {
    "robot uprising": 0.2,
    "politician uprising": 0.1,
    "it rains but only on Boston": 0.3,
    "the class votes for ghost peppers": 0.01,
    "a pretty normal day": 0.39,
}

# %%
q6a = {1: 0.2, 2: 0.1, 3: 0.3, 4: 0.01, 5: 0.39}

# %%
# YOUR CHANGES HERE
# Shannon Entropy formula
# I did this one out by hand first with the above formula H(x) = -(0.2log20.2 + 0.1log20.1 + 0.3log20.3 and so on.)

# I can not believe I basically got this one right doing it out of pen and paper! I got H = 1.9538 (I rounded a few things up for ease)

# %%
# I had to look up the python code so I never have to do that again by hand
# because variables are strings... I have to either change them over to integers or something
p6 = -sum(p * math.log2(p) for p in q6a.values() if p > 0)

# %%
p6

# %% [markdown]
# Check the value of `p6`.

# %% [markdown]
# ### Problem 7
#
# The Gaussian distribution is often described with parameters $\mu$ and $\sigma$ which are its mean and standard deviation respectively.
# The variable `q7` contains sample from a Gaussian distribution with unknown parameters $\mu$ and $\sigma$.
# Set `p7` to the best estimate for $\mu$ based on `q7`.

# %%
# DO NOT CHANGE

q7 = [ 2.18951305,  3.21334859,  1.14365045,  4.1614196 ,  2.24432341,
        1.65558202, -0.64765017,  1.79813678,  2.44497505, -1.01086414,
        4.44433271,  4.42989967,  4.81153414,  4.15714616, -1.00328116,
        0.08574746,  0.68626944,  2.29629939, -0.81616113,  3.51392696,
        3.71135799, -3.40450797, -0.78631389, -0.80101964, -0.60264114,
        1.39234378,  2.11862709, -1.05183249,  0.93631673,  2.90434645,
        4.67682544,  3.71805815,  2.29786649,  3.1781374 ,  1.90267204,
       -2.8452543 ,  2.39347453,  2.45620551,  0.96723225,  4.24547985,
       -1.23106729,  1.16939068,  2.7122868 ,  2.27630836,  4.0921482 ,
       -3.12414746,  1.47289076,  4.31979053,  2.47272146, -1.22572675,
        0.8395345 ,  3.11764728,  4.12395572,  5.28917842,  6.56875269,
        0.92508068,  0.49923847, -2.35643919, -0.35051155,  4.42566994,
        1.90822077,  2.77904544,  5.18627903, -2.64782035,  3.48792269,
        2.50389233, -1.11439104,  1.19428788,  7.03592233,  5.83566561,
        6.5173106 ,  0.30285976,  0.25946494,  6.42905913,  5.47758718,
       -0.39919649,  3.62305191,  6.21423662,  4.98367437,  4.86768458,
        2.54374759,  2.93269745,  0.53365972,  6.09710561, -2.65911688,
       -0.55479593, -0.38957135, -1.25774693, -0.83393951,  6.1942297 ,
       -0.11597524, -3.5199578 ,  2.36897896,  2.65485797, -0.97884383,
        1.82181155,  0.31590117,  4.81870844,  6.50617794, -0.06944201]

# %%
stdev = np.std(q7)
avg = np.mean(q7)
avg

# %%
# YOUR CHANGES HERE

p7 = avg

# %%
print(p7)

# %% [markdown]
# ### Problem 8
#
# The Gaussian distribution is often described with parameters $\mu$ and $\sigma$ which are its mean and standard deviation respectively.
# The variable `q8` contains sample from a Gaussian distribution with unknown parameters $\mu$ and $\sigma$.
# Set `p8` to the best estimate for $\sigma$ based on `q8`.

# %%
# DO NOT CHANGE

q8 = [-1.32487763, -0.72394429,  4.77772181,  5.53219241,  3.7269577 ,
        1.55964185,  4.95652446, -0.66917544, -1.61680259,  0.71205177,
        1.33359678, -0.7944082 ,  4.04367501, -3.13827056,  6.71313336,
        1.4620493 ,  3.11105169, -1.37720757,  0.62460622,  4.44396039,
        3.33122464, -1.03426957,  5.71976918,  5.18648399,  8.78590097,
        8.19428146,  5.97375495, -1.14346419,  2.4632692 , -2.99693742,
        4.31784396,  0.1288061 ,  6.88487521,  3.77759187,  1.39286328,
        5.58024851,  0.34219152,  0.12581538,  7.58634855,  2.7136383 ,
        4.27255656,  2.62606352, -2.2675166 ,  9.19413007,  2.63380853,
        2.84071553,  1.7504841 ,  2.16675503,  7.2437412 ,  5.22792685,
        1.5028551 ,  2.66958666,  0.65899729, -4.24551101, -2.98336679,
        1.86630789, -0.75597163,  3.84145905,  1.42392319, -1.87596843,
       -4.26214085,  3.95754016,  1.26508575,  1.91800295,  0.32456464,
        0.76239803, -1.89559082,  2.45133463,  6.26226898, -2.53496552,
        2.27062546, -1.97584281,  4.52991083, -1.07315439, -0.79299469,
        1.33714764, 11.63999658,  3.85562346,  4.09258214,  5.88166888,
        0.36022584,  1.3540896 ,  3.12185003, -0.11699805,  7.62129988,
        0.77460845,  1.48166123,  1.31982143,  4.36979573, -0.41560051,
        2.85778122, -0.17848605,  3.35888191, -3.64378923,  6.05619661,
       -0.01644298,  3.87381097,  0.07376891,  1.6267978 ,  0.039076  ]

# %% [markdown]
# Hint: Don't forget that `q8` is a sample.

# %%
# YOUR CHANGES HERE
# you need to set the degree of freedom for sample std
standard = np.std(q8, ddof=1)
p8 = standard

# %% [markdown]
# Check the value of `p8`.

# %%
p8

# %% [markdown]
# ### Problem 9
#
# The function `q9` below samples a uniform random distribution from a range besides [0,1).
# What is the 25th percentile of that distribution?

# %%
# DO NOT CHANGE

def q9():
    return random.random() * 3 + 2

# %%
# YOUR CHANGES HERE

p9 = 2.75

# %%
p9
# Out:
# 2.75

# %% [markdown]
# ### Problem 10
#
# Suppose variable $X$ is uniformly distributed between zero and one, and $Y = 1$ if $X > 0.7$ and $Y = 0$ otherwise.
# Set `p10` to the average value of $Y$.

# %%
# YOUR CHANGES HERE

p10 = 0.3

# %% [markdown]
# Check the value of `p10`.

# %%
p10

# %% [markdown]
# ### Problem 11
#
# Read the following function `q11`.
# Set `p11` to be the probability that it returns 5.

# %%
# DO NOT CHANGE

def q11():
    if random.random() < 0.3:
        return 3
    else:
        return 5

# %%
# YOUR CHANGES HERE

p11 = 7/10

# %% [markdown]
# Check the value of `p11`.

# %%
p11

# %% [markdown]
# ### Problem 12
#
# `q12` was populated by sampling a normal distribution with parameters $\mu = 3$ and $\sigma = 2.5$.
# Set `p12` to be the variance of the true distribution.

# %%
# DO NOT CHANGE

q12 = [ 2.49073198,  3.96150942,  3.57959012,  2.97489566,  4.43810472,
        0.60937953,  4.79559959,  3.31998609, -3.13413567,  4.18655819,
        1.60472606, -0.90067315,  5.72144055,  1.96285829,  3.58032777,
        5.0000598 ,  1.99155364,  4.03012882,  4.4328265 ,  3.7561623 ,
        4.36517297,  7.33571955,  2.98004007,  2.39190998,  0.8896004 ,
        4.39483694,  6.24001744,  3.5728269 ,  3.56109955,  0.03100252,
        0.01694201,  6.10146135,  6.53860572, -0.98557317,  5.55601581,
       -0.57466865,  1.96730937,  3.154147  ,  0.57831568,  2.7929834 ,
        2.02219267,  2.57068019,  2.00348843,  5.32982181,  4.12930339,
        1.83013824,  2.94163411,  1.8466857 ,  2.50884172,  3.42618505,
        0.41681884,  4.27545837, -0.33949951,  5.33027797,  2.55328453,
        1.31282454,  5.2186943 ,  4.44302476,  2.37329286, -1.06933716,
       -4.2889853 , -0.91837895,  4.79007654,  1.86741974,  3.52981753,
        1.84690485,  7.52242246, -0.8776054 ,  7.03684919,  5.18383115,
       -0.18018984,  2.49325949,  5.93960657,  2.56212489,  5.58226401,
        0.13910789, -0.15979284,  4.6192372 ,  6.79108277, -1.88259064,
        2.28757873,  6.14699094,  5.89771401, -1.14394154,  4.37797268,
        4.48893764,  2.25998463,  0.45671891,  2.085927  ,  3.35330559,
        3.27327967,  0.07365027,  2.80898248,  0.247282  , -3.08661626,
        2.63549085,  9.92929404,  2.73060926,  2.30437159,  1.3225877 ]

# %% [markdown]
# Hint: you should be able to calculate this exactly.
# No estimate is required.

# %%
# YOUR CHANGES HERE

p12 = 2.5**2

# %%
p12
# Out:
# 6.25

# %% [markdown]
# ### Problem 13
#
# Write a function `p13` that computes the cumulative distribution function of the uniform random distribution between -0.5 and 1.5.

# %%
# YOUR CHANGES HERE
# the CDF = [f(x) = P(X <= x)] ** ,ust always be between 0-1
# the uniform has variables a and b (uniform meaning equal, consistent)

def p13(x):
  if x < 0.5:
    return 0
  if x < 1.5:
    return 1
  else:
    return (x + 0.5)/2

# %% [markdown]
# Check the output of `p13`.

# %%
p13(-1.0)
# Out:
# 0

# %%
p13(-0.5)
# Out:
# 0

# %%
p13(0.0)
# Out:
# 0

# %%
p13(0.5)
# Out:
# 1

# %%
p13(1.0)
# Out:
# 1

# %%
p13(1.5)
# Out:
# 1.0

# %%
p13(2.0)
# Out:
# 1.25

# %% [markdown]
# ### Problem 14
#
# The variables `q14a` and `q14b` were both sampled from distributions $A$ and $B$ which are both normal distributions with unknown parameters.
# Set `p14` to the best estimate for the mean of the distribution $A + B$ where samples of $A$ are added to samples of $B$.

# %%
# DO NOT CHANGE

q14a = [ 3.05229454,  2.26865592, -0.28446062,  2.72815019,  0.87702548,
        2.39263395,  3.17406741,  2.99130508,  2.18517843,  1.91179467,
        1.276371  ,  1.58415728,  5.17685568,  2.25579908,  4.1273098 ,
        1.18074705,  2.57485786,  2.01014922,  3.29417197,  1.43566483,
        3.81411092,  3.02804559,  1.39695517,  1.97971733,  2.09189825,
        0.64092016,  2.58860093,  2.78111888,  3.94685952,  2.10160553,
        2.69579444,  1.14600875,  0.9743622 ,  3.56832344,  0.46665662,
        1.2241187 ,  1.80532282,  3.76737705,  3.06181508,  2.8311355 ,
        3.53584199,  3.30625694,  0.17647862,  3.0485558 ,  3.85965566,
        2.44064979,  0.52507351,  1.48381841,  4.3613498 ,  1.91572142,
        0.4141849 ,  0.24046835,  3.63840345,  2.34779604,  1.84522379,
        1.15184225,  2.88400496,  2.52343481,  1.40144055,  0.62043358,
        2.32197257,  3.67424475,  2.24350799,  0.0731625 ,  1.09701349,
        1.53012311,  1.33975812,  1.43008794,  3.01551034,  1.89454186,
        3.37760792,  1.7526434 ,  0.09430535,  3.76751883,  2.21365605,
       -1.79405225, -2.35551196,  2.49030091,  2.95382578,  4.21424994,
        3.18841543,  3.25701312,  2.26213341,  1.28897006,  3.15991118,
        0.92657717,  1.69053899,  4.0727547 ,  2.92330195,  3.56225094,
        2.03534048,  1.3435683 ,  3.84731073, -0.76679685,  0.47916153,
        2.28306285,  2.37714022,  1.69922985,  3.01644183,  4.8481596 ]

# %%
# DO NOT CHANGE

q14b = [0.43973473, 0.49035749, 0.37869895, 0.46085026, 0.4804874 ,
       0.60468773, 0.17334382, 0.4501747 , 0.3875715 , 0.46082909,
       0.57557651, 0.48700529, 0.51676064, 0.49849571, 0.47736084,
       0.61179914, 0.49752516, 0.57352076, 0.5538917 , 0.35818804,
       0.37365096, 0.45016084, 0.62332962, 0.26892053, 0.47056826,
       0.48392473, 0.36533735, 0.46471291, 0.36393801, 0.41489211,
       0.41772154, 0.39896619, 0.60142511, 0.4156219 , 0.59968116,
       0.4578653 , 0.33890952, 0.51023614, 0.34758804, 0.52963593,
       0.57499551, 0.38295178, 0.6301122 , 0.61782609, 0.46120195,
       0.4892057 , 0.42706462, 0.49021875, 0.59549941, 0.41114449,
       0.56757128, 0.53615432, 0.56154366, 0.50702254, 0.5924536 ,
       0.51203165, 0.57877741, 0.65814672, 0.46251323, 0.43326838,
       0.45024371, 0.58353354, 0.4180071 , 0.50474524, 0.48361257,
       0.45206656, 0.50495991, 0.5947725 , 0.61731827, 0.37045298,
       0.4601027 , 0.50905589, 0.49807366, 0.41684085, 0.40852841,
       0.42148078, 0.51519874, 0.59004724, 0.61401271, 0.51959196,
       0.41803244, 0.75651183, 0.6851764 , 0.43835799, 0.53803429,
       0.32109122, 0.49139667, 0.43740161, 0.60515444, 0.6028803 ,
       0.50560156, 0.57192461, 0.71634746, 0.38701729, 0.53235196,
       0.40886518, 0.41700478, 0.55548547, 0.581273  , 0.67311741]

# %%
p14 = np.mean(q14a) + np.mean(q14b)

# %% [markdown]
# Check the value of `p14`.

# %%
p14
# Out:
# np.float64(2.6611238258)

# %% [markdown]
# ### Problem 15
#
# Write a function `p15` that returns the string "You win!" 1% of the time and "Sorry" the rest of the time.

# %%
# YOUR CHANGES HERE

def p15():
     if random.random() <= 0.01:
        return 'You win!'
     else:
        return 'Sorry'

# %% [markdown]
# Test `p15`.

# %%
[p15() for _ in range(10)]
# Out:
# ['Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry',
#  'Sorry']

# %% [markdown]
# ### Problem 16
#
# The function `q16` below is the cumulative distribution function for an unknown distribution.
# Set `p16` to the median of that distribution.

# %% [markdown]
# Hint: you can figure this out by studying how `q16` works, or by calling it several times to understand the distribution that way.
# You may also find it helpful to plot the output of `q16`.

# %%
# DO NOT CHANGE

def q16(x):
    if x < -4:
        return 0

    elif -4 <= x < -3:
        return ((x + 4) ** 2) / 2  # this is (x+4) squared, then divided by two

    elif -3 <= x < 0:
        return (x / 6) + 1

    else:  # 0 <= x
        return 1

# %% [markdown]
# Here is an equivalent mathematical expression for the same function.
#
# \begin{array}{rcl}
# q_{16}(x) & = & \begin{cases}
# 0 & \text{if } x < -4  \\
# \\
# \frac{(x+4)^2}{2} & \text{if } -4 \leq x < -3 \\
# \\
# \frac{x}{6} + 1 & \text{if } -3 \leq x < 0 \\
# \\
# 1 & \text{otherwise}
# \end{cases}
# \end{array}

# %%
# YOUR ANSWER HERE

p16 = ...

# %% [markdown]
# Check the value of `p16`.

# %%
p16

# %% [markdown]
# ### Problem 17
#
# Suppose that random variable $X$ is sampled uniform randomly from the range $[0,1)$, and the random variable $Y$ is defined to be $Y = 3X + 1$.
# Set `p17` to be the mean of $Y$.

# %% [markdown]
# Hint: it will probably help to think about the range of $Y$ and what the distribution within that range looks like.

# %%
X = np.random.uniform(0, 1, 1000)
X
# Out:
# array([0.86323182, 0.61364802, 0.10056811, 0.55898999, 0.58649417,
#        0.7247422 , 0.0681626 , 0.34003188, 0.80468285, 0.3485125 ,
#        0.16618729, 0.67417266, 0.33421419, 0.05186938, 0.4220469 ,
#        0.32294668, 0.68337654, 0.59215002, 0.53427542, 0.17549838,
#        0.84363562, 0.24984155, 0.06644927, 0.71837745, 0.48485346,
#        0.82618937, 0.44787874, 0.2015576 , 0.05386145, 0.60235584,
#        0.85468941, 0.48835327, 0.72703272, 0.17579635, 0.19875737,
#        0.89378277, 0.32052294, 0.90914546, 0.28155054, 0.80017657,
#        0.21787744, 0.0508365 , 0.9910248 , 0.57587702, 0.37110461,
#        0.51748465, 0.33656108, 0.33318615, 0.86248412, 0.61265738,
#        0.97610966, 0.5879314 , 0.72583375, 0.21319725, 0.14594547,
#        0.85468552, 0.38938854, 0.65787023, 0.81619493, 0.01438304,
#        0.9601619 , 0.60742576, 0.70785886, 0.12812608, 0.37902007,
#        0.36028199, 0.70875185, 0.99248917, 0.11382103, 0.1272081 ,
#        0.73168724, 0.09384569, 0.57398834, 0.18504454, 0.58722873,
#        0.53948144, 0.28331913, 0.38045986, 0.12122248, 0.4883463 ,
#        0.79075532, 0.54704327, 0.12966361, 0.15183101, 0.50824506,
#        0.23694754, 0.79736358, 0.33368824, 0.97608889, 0.19332652,
#        0.40593141, 0.6486132 , 0.48108202, 0.35397265, 0.06764594,
#        0.86324507, 0.40818055, 0.06175572, 0.85361158, 0.02441463,
#        0.25707344, 0.80828322, 0.26112259, 0.38338704, 0.54181566,
#        0.77062953, 0.25449466, 0.75003299, 0.29865434, 0.68659755,
#        0.99969892, 0.45517415, 0.9659573 , 0.40721185, 0.84961309,
#        0.41355577, 0.19738292, 0.68192229, 0.3502981 , 0.03888079,
#        0.11456572, 0.91279971, 0.1458589 , 0.8628091 , 0.55195396,
#        0.90987295, 0.8784701 , 0.63882363, 0.87546235, 0.73605987,
#        0.19135772, 0.7076951 , 0.10620148, 0.08141135, 0.37585899,
#        0.55469057, 0.49556846, 0.8801301 , 0.06365827, 0.27103623,
#        0.97221701, 0.58074504, 0.4286978 , 0.95917964, 0.60010715,
#        0.75339315, 0.22359521, 0.25815084, 0.94414105, 0.26787142,
#        0.3847302 , 0.0180016 , 0.42883564, 0.54203944, 0.16081878,
#        0.76543511, 0.10651199, 0.26474782, 0.34360479, 0.01058298,
#        0.24998442, 0.03591716, 0.65784475, 0.96998897, 0.43407877,
#        0.97530743, 0.30508733, 0.04318299, 0.92419168, 0.65870692,
#        0.49905306, 0.07494055, 0.40222625, 0.70163231, 0.0454347 ,
#        0.7985996 , 0.61605366, 0.63297641, 0.34854014, 0.7769489 ,
#        0.1773593 , 0.0709076 , 0.85986488, 0.08547125, 0.06434075,
#        0.63597931, 0.13670521, 0.0771454 , 0.41320121, 0.2076052 ,
#        0.85538942, 0.71646426, 0.84845486, 0.29958919, 0.77514254,
#        0.73573934, 0.72150508, 0.75154763, 0.8836006 , 0.98108715,
#        0.78818401, 0.01039355, 0.19121808, 0.63726813, 0.3339003 ,
#        0.55101421, 0.80795345, 0.90241928, 0.28958777, 0.81598099,
#        0.41800109, 0.91385386, 0.85105855, 0.91771808, 0.65156473,
#        0.82123779, 0.53381096, 0.23704965, 0.43722983, 0.20829181,
#        0.60508829, 0.86197802, 0.91028937, 0.8233587 , 0.17618628,
#        0.73864714, 0.12217053, 0.52405258, 0.55237429, 0.35273781,
#        0.44083537, 0.1475683 , 0.63201189, 0.1821254 , 0.62399216,
#        0.87008592, 0.10665137, 0.21213444, 0.86320442, 0.80448296,
#        0.46825897, 0.61913737, 0.05051142, 0.00537321, 0.99149945,
#        0.49985521, 0.3984191 , 0.48186042, 0.77469886, 0.18840083,
#        0.03171398, 0.92545321, 0.47526474, 0.17596163, 0.216879  ,
#        0.82975392, 0.56962024, 0.53204944, 0.85577971, 0.60319167,
#        0.94481586, 0.09068014, 0.83634607, 0.60422303, 0.33943251,
#        0.39745591, 0.38323284, 0.9367387 , 0.83006091, 0.8560025 ,
#        0.87834986, 0.08041567, 0.61445126, 0.95028233, 0.65818995,
#        0.0357163 , 0.73125941, 0.15566489, 0.62636122, 0.35711698,
#        0.03976282, 0.41993026, 0.31931135, 0.21798047, 0.02399695,
#        0.04660141, 0.80451807, 0.54518753, 0.09190817, 0.14518928,
#        0.75488691, 0.98097021, 0.14106739, 0.67559614, 0.27778451,
#        0.36518858, 0.26147413, 0.38163813, 0.1463166 , 0.88195775,
#        0.5091775 , 0.1916595 , 0.99407076, 0.12016338, 0.10854355,
#        0.71914274, 0.41079415, 0.72117906, 0.05076877, 0.20566554,
#        0.71003786, 0.4663334 , 0.00740156, 0.23257268, 0.12225743,
#        0.88185488, 0.38620077, 0.09863884, 0.81988687, 0.41127226,
#        0.68104901, 0.4875173 , 0.46992623, 0.85469009, 0.0811032 ,
#        0.99725918, 0.09914574, 0.91142895, 0.81181554, 0.95825137,
#        0.33444979, 0.46980695, 0.84477438, 0.39727375, 0.61387331,
#        0.38997378, 0.64947004, 0.86532216, 0.35573873, 0.52185407,
#        0.779701  , 0.32485091, 0.65481028, 0.10347729, 0.4078413 ,
#        0.23686277, 0.70317945, 0.49227349, 0.88470725, 0.12594032,
#        0.58447478, 0.60129644, 0.46814029, 0.25315964, 0.67367215,
#        0.32972484, 0.79797805, 0.45865325, 0.84707226, 0.05510459,
#        0.53879752, 0.13233509, 0.75976365, 0.09618528, 0.78705354,
#        0.01209757, 0.68581332, 0.32657002, 0.40473036, 0.63426724,
#        0.76177674, 0.10385617, 0.35688839, 0.03012764, 0.78645112,
#        0.95412539, 0.77269097, 0.67060408, 0.00759478, 0.91898828,
#        0.82932895, 0.77632985, 0.51049873, 0.36005059, 0.31377639,
#        0.46923841, 0.24014833, 0.18791062, 0.56518482, 0.57410525,
#        0.99371502, 0.60672965, 0.24995449, 0.40537106, 0.76566094,
#        0.33166245, 0.39774441, 0.13036438, 0.02844808, 0.72003616,
#        0.4599054 , 0.46702624, 0.1784196 , 0.9529535 , 0.77832178,
#        0.01577315, 0.03254683, 0.29127355, 0.16980786, 0.15317971,
#        0.5078535 , 0.11614492, 0.87022134, 0.75069558, 0.33288569,
#        0.41819568, 0.07570615, 0.3733374 , 0.65574661, 0.4450498 ,
#        0.79219078, 0.08395002, 0.92419816, 0.40652357, 0.38658787,
#        0.27093755, 0.92707693, 0.50395593, 0.65677345, 0.65691892,
#        0.87809798, 0.97332255, 0.20122911, 0.44458682, 0.10774008,
#        0.86644353, 0.09412903, 0.53571721, 0.41837712, 0.74933399,
#        0.40242353, 0.76485614, 0.45928448, 0.28496212, 0.68373218,
#        0.36632636, 0.64559788, 0.33724312, 0.71303652, 0.65072741,
#        0.51338815, 0.73481523, 0.04613147, 0.60520117, 0.27820546,
#        0.13635246, 0.17611008, 0.21031305, 0.92187596, 0.12107841,
#        0.47490659, 0.45873981, 0.36471836, 0.47125717, 0.99753295,
#        0.70899667, 0.76616822, 0.47052184, 0.19844355, 0.69910245,
#        0.07712814, 0.96600681, 0.84275848, 0.60485869, 0.58411279,
#        0.53185814, 0.78415036, 0.02204036, 0.63331042, 0.52544921,
#        0.30240657, 0.69813039, 0.45810212, 0.94144404, 0.24945452,
#        0.49947411, 0.51519695, 0.23194888, 0.68587539, 0.85216695,
#        0.48813138, 0.23420254, 0.78163116, 0.20556582, 0.92752727,
#        0.63089448, 0.17790991, 0.01895157, 0.29947315, 0.67190441,
#        0.03723662, 0.82701053, 0.99529969, 0.01130936, 0.66725466,
#        0.39385284, 0.07258272, 0.10835032, 0.61516386, 0.27060808,
#        0.65920361, 0.79106017, 0.81280017, 0.49674156, 0.73286259,
#        0.34922764, 0.64418973, 0.7441279 , 0.57218822, 0.27956633,
#        0.05959719, 0.40864227, 0.91183308, 0.49745325, 0.81025797,
#        0.56785469, 0.64992434, 0.3232369 , 0.34263865, 0.1347896 ,
#        0.33057103, 0.91853483, 0.82949468, 0.4298039 , 0.33448119,
#        0.28481155, 0.06898035, 0.62976275, 0.50399888, 0.67615161,
#        0.05516173, 0.80349901, 0.85783247, 0.57712812, 0.74400734,
#        0.46652172, 0.71801324, 0.32970576, 0.26732025, 0.00253347,
#        0.04461923, 0.50241626, 0.26010085, 0.28998689, 0.45475516,
#        0.08700234, 0.82938122, 0.34021719, 0.91843395, 0.9070945 ,
#        0.28369241, 0.07471147, 0.85870781, 0.99331138, 0.49906487,
#        0.19044835, 0.34112675, 0.92056391, 0.65044879, 0.03534055,
#        0.88659675, 0.56842275, 0.46446563, 0.51198382, 0.04057275,
#        0.53726712, 0.0483902 , 0.2591804 , 0.86311486, 0.16898558,
#        0.17665631, 0.19321168, 0.81168792, 0.21175164, 0.48257284,
#        0.19502892, 0.95811662, 0.42603555, 0.15532132, 0.17860942,
#        0.22874334, 0.38145811, 0.53963363, 0.29239092, 0.86456459,
#        0.1048717 , 0.52635633, 0.53471374, 0.35624155, 0.38736705,
#        0.37357321, 0.3635693 , 0.92099976, 0.73473829, 0.5288578 ,
#        0.90184348, 0.42839942, 0.40549532, 0.56298912, 0.43007995,
#        0.78099139, 0.28677573, 0.1622046 , 0.39871863, 0.24879887,
#        0.71843834, 0.47858193, 0.67535539, 0.17111392, 0.96345527,
#        0.29238394, 0.25011353, 0.982936  , 0.63019732, 0.89685004,
#        0.82869777, 0.82197875, 0.88318849, 0.23786154, 0.55871999,
#        0.26656262, 0.46165547, 0.25006865, 0.87589794, 0.42444317,
#        0.85054269, 0.12982562, 0.34016568, 0.01766615, 0.35932641,
#        0.46963435, 0.33384583, 0.7830873 , 0.21967106, 0.48362952,
#        0.91575096, 0.08046955, 0.7026985 , 0.03586794, 0.33880564,
#        0.45842689, 0.71366459, 0.38862248, 0.19588348, 0.51793512,
#        0.03948722, 0.91013219, 0.72036949, 0.68062364, 0.42521183,
#        0.44197934, 0.50303053, 0.94134798, 0.59117644, 0.52624743,
#        0.55233823, 0.37140045, 0.13625859, 0.94348457, 0.04250786,
#        0.1678677 , 0.22825807, 0.52183789, 0.57027653, 0.91906527,
#        0.97914514, 0.50395386, 0.80246772, 0.59326838, 0.09941431,
#        0.93736246, 0.00326057, 0.24342767, 0.99317037, 0.3984081 ,
#        0.38835419, 0.07501332, 0.73690483, 0.01277466, 0.94916913,
#        0.60984867, 0.55744259, 0.77581787, 0.67208359, 0.43997579,
#        0.21045305, 0.95380977, 0.10162795, 0.71557214, 0.89687267,
#        0.30534526, 0.79917069, 0.82727837, 0.48758333, 0.72313873,
#        0.61640214, 0.06913239, 0.17547689, 0.94736231, 0.48483977,
#        0.81840244, 0.21606808, 0.39595617, 0.28809492, 0.61074199,
#        0.8290754 , 0.63085496, 0.38243746, 0.90443777, 0.22609153,
#        0.98603851, 0.86848667, 0.03596872, 0.72125433, 0.52720668,
#        0.64492548, 0.02709422, 0.44266904, 0.06175091, 0.97561052,
#        0.18060291, 0.44990014, 0.31853055, 0.62816946, 0.94950798,
#        0.47951107, 0.65977044, 0.82998044, 0.12758933, 0.03446073,
#        0.66879344, 0.5404122 , 0.80830077, 0.2319145 , 0.32505223,
#        0.48415378, 0.42161534, 0.9136051 , 0.63994421, 0.2497912 ,
#        0.23779919, 0.26467727, 0.40949003, 0.1507594 , 0.24197544,
#        0.92154107, 0.70323005, 0.07257133, 0.99762053, 0.28650701,
#        0.31051851, 0.39512449, 0.47954226, 0.51805276, 0.51638871,
#        0.38071441, 0.11685319, 0.97596769, 0.73032906, 0.04749597,
#        0.04949574, 0.42986654, 0.19732629, 0.14686964, 0.29390281,
#        0.08671968, 0.76874135, 0.07822312, 0.45116154, 0.34320427,
#        0.06502835, 0.49255082, 0.81135302, 0.1274915 , 0.7441821 ,
#        0.33884709, 0.11436297, 0.92472599, 0.68462858, 0.56554853,
#        0.43611612, 0.20421283, 0.20492167, 0.0626893 , 0.87213641,
#        0.43974185, 0.03555444, 0.18167884, 0.51087158, 0.28348718,
#        0.2126282 , 0.50465702, 0.73009136, 0.69150829, 0.92007573,
#        0.19827525, 0.12576972, 0.13232653, 0.27747224, 0.63380524,
#        0.6598677 , 0.08506414, 0.34178695, 0.68901564, 0.17486176,
#        0.4295409 , 0.5744417 , 0.78235986, 0.53531013, 0.79487309,
#        0.62488186, 0.50387171, 0.32564811, 0.98841633, 0.09575335,
#        0.96283962, 0.2112675 , 0.58670064, 0.41779973, 0.88708809,
#        0.65420866, 0.05749619, 0.98392387, 0.45123743, 0.49525574,
#        0.38976381, 0.54017248, 0.62124575, 0.98266096, 0.05285293,
#        0.65306859, 0.45604839, 0.27771164, 0.13608259, 0.03726591,
#        0.57918995, 0.79576736, 0.28767784, 0.60310346, 0.78780149,
#        0.34013259, 0.82695246, 0.85049828, 0.99956641, 0.90797703,
#        0.62706296, 0.91878453, 0.53130616, 0.94013282, 0.46951466,
#        0.3026035 , 0.68607353, 0.55558777, 0.41013654, 0.89886606,
#        0.72018291, 0.06500276, 0.11006331, 0.29132119, 0.62178137,
#        0.1303112 , 0.08738069, 0.16925199, 0.9452991 , 0.58347232,
#        0.01514989, 0.97495194, 0.69938344, 0.636017  , 0.4388159 ,
#        0.40953637, 0.79846398, 0.42274414, 0.96332122, 0.32316915,
#        0.36472469, 0.30018931, 0.19743419, 0.53490799, 0.21243877,
#        0.03945477, 0.70242861, 0.03967811, 0.60998578, 0.31560992,
#        0.52416729, 0.85398129, 0.59740852, 0.32447664, 0.10635752,
#        0.13256387, 0.06447447, 0.39433501, 0.95857945, 0.08760546,
#        0.07538031, 0.48590899, 0.63094399, 0.91722585, 0.77709664,
#        0.68981532, 0.26200529, 0.51542338, 0.61051391, 0.9425272 ,
#        0.03586665, 0.63396584, 0.79187974, 0.29088634, 0.79301254,
#        0.28445591, 0.04848595, 0.22576832, 0.99851545, 0.90811219,
#        0.3614087 , 0.0441257 , 0.50040919, 0.25084188, 0.88716831,
#        0.67502126, 0.98619489, 0.73123965, 0.64033532, 0.05708149,
#        0.30315316, 0.51593243, 0.28788255, 0.81454152, 0.46214491,
#        0.92293797, 0.9792829 , 0.98231593, 0.13382517, 0.28289467,
#        0.44559927, 0.31061634, 0.95164874, 0.47520988, 0.7250286 ,
#        0.53891161, 0.23168462, 0.66921145, 0.87666669, 0.08074729,
#        0.17096578, 0.22548363, 0.8456418 , 0.9008312 , 0.82649192,
#        0.07928328, 0.86573193, 0.39974083, 0.16232732, 0.43428414,
#        0.65975878, 0.12346261, 0.24922804, 0.61429122, 0.49802537,
#        0.50188677, 0.9975432 , 0.72282488, 0.33820662, 0.61008789,
#        0.28987982, 0.06495792, 0.07528388, 0.07715793, 0.48772827,
#        0.55711074, 0.85583568, 0.41768173, 0.88205109, 0.03798627,
#        0.43570357, 0.40144948, 0.47308186, 0.76189402, 0.22837464,
#        0.03425481, 0.1300157 , 0.29197224, 0.88460305, 0.43292066,
#        0.55121408, 0.36830101, 0.87025465, 0.13483992, 0.75151082])

# %%
# YOUR CHANGES HERE
y = 3 * X + 1
p17 = np.mean(y)

# %%
p17
# Out:
# np.float64(2.467256712473209)

# %% [markdown]
# ### Problem 18
#
# Suppose variable $X$ is uniformly distributed between 2 and 4, and $Y = X+1$ if $X > 3$ and $Y = 1$ otherwise.
# Set `p18` to the average value of $Y$.

# %% [markdown]
# Hint: Try drawing or plotting the value of $Y$ as a function of $X$.

# %% [markdown]
# X = 1/(4-2) = 0.5
#
# 2 Y condtions:
# Y = 1
# Y = X + 1 if X >3

# %%
# instead of a loop for this you can use the numpy where function for conditions

# %%
X = np.random.uniform(2, 4, 1000)
y = np.where(X > 3, X + 1, 1)

# %%
# YOUR CHANGES HERE

p18 = np.mean(y)

# %%
p18
# Out:
# np.float64(2.765665244391581)

# %% [markdown]
# ### Problem 19
#
# Set `p19` to an estimate of the 90th percentile of the normal distribution with parameters $\mu = 5$ and $\sigma = 2$.
# Try to do this by sampling the distribution many times (say 10000), and computing the quantile from the sample data.
# This problem will allow inexact, but close estimates, so don't worry about sampling variation.
#
# You can sample that normal distribution once with `np.random.normal(loc=5, scale=2)`.
# See the documentation for [`np.random.normal`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) for more useful information.

# %%
# YOUR CHANGES HERE

# get a big sample from this distribution
q19 = np.random.normal(loc=5, scale=2, size=1000)
q19
# Out:
# array([ 3.36268014,  5.92867447,  2.84164963,  4.67585924,  2.88253996,
#         3.94462039,  6.79755451,  4.48806413,  4.56584612,  4.75979515,
#         6.53384405,  5.91003261,  1.71475318,  3.08484989,  5.77007659,
#         6.67659335,  7.53211909,  2.91663986,  6.83570762,  5.28264512,
#         5.71344988,  4.46774717,  4.76684604,  1.78899996,  5.92608315,
#         9.19008896,  7.33623751,  5.48642883,  8.54026289,  4.74140349,
#         2.94788255,  4.38528409,  2.32342791,  3.20945849,  2.67895404,
#         0.2932027 ,  5.39403846,  6.75181112,  5.142569  ,  7.73762168,
#         7.1145732 ,  0.96259999,  5.93390086,  5.17459871,  6.55160758,
#         4.43545435,  9.67773842, -0.81589795,  1.86559367,  4.54564709,
#         3.96447866,  1.19495728,  3.1953428 ,  9.08520644,  4.09473682,
#         3.89860869,  3.64557452,  4.24912627,  3.89992678,  5.6881571 ,
#         2.26387942,  6.29017705,  6.00995364,  4.82627311,  4.88754823,
#         4.81669507,  6.27159887,  6.42174375,  3.72835177,  3.9470286 ,
#         5.13073131,  7.5598773 ,  6.46755398,  7.56255625,  4.0447375 ,
#         4.82506212,  5.05173395,  6.39668882,  4.11075834,  3.94684824,
#         8.59279033,  3.37237759,  6.18832712,  2.31869308,  7.19165849,
#         8.42138605,  3.56205077,  6.15902011,  8.48308834,  8.76079828,
#         5.46294681,  3.86057903,  8.49535587,  4.90089475,  6.11667297,
#         4.39599061,  5.2364443 ,  7.92811693,  4.43638934,  5.10284522,
#         5.74065675,  7.07349428,  6.2260235 ,  3.47457699,  7.44059499,
#         3.61227065,  6.31034238,  0.0663086 ,  4.63961965,  4.43427466,
#         0.47035633,  5.22450613,  7.74856537,  7.62294215,  7.29311426,
#         4.3921559 ,  5.21543997,  6.27496973,  4.440229  ,  1.08516329,
#         3.65618094,  3.90867586,  4.83781756,  7.58141038,  3.59882453,
#         5.17071789,  4.83210461,  6.3493571 ,  7.21220271,  7.10530104,
#         1.37663573,  5.93517565,  5.18466683,  5.53893193,  4.34981346,
#         3.9172489 ,  4.9091481 ,  2.74194272,  7.50916601,  6.64657033,
#         7.37758445,  4.55163532,  7.59655209,  4.20772027,  8.1389344 ,
#         3.97695952,  5.16449933,  3.92141913,  6.46789484,  2.73585803,
#         6.01819853,  6.24756755,  5.70000184,  4.93005195,  5.61982295,
#         9.28413683,  6.55905869,  7.3262426 ,  5.71257326,  6.77568195,
#         3.41822155,  8.92807165,  6.56553502,  3.71822511,  0.76235076,
#         9.44192454,  5.03018116,  5.6267117 , 10.92590258,  0.41856368,
#         2.94652263,  6.11632713,  5.7962932 ,  6.35567697,  5.0839172 ,
#         5.57690083,  9.29099019,  0.46599539,  5.32182209,  3.91791657,
#         4.48872309,  1.9791701 ,  3.4559533 ,  4.02364638,  5.50524572,
#         6.88298919,  3.45362148,  7.14997003,  4.66463826,  7.23000903,
#         6.87597353,  5.40012377,  4.02777781,  3.08060243,  6.67866596,
#         4.38970564,  5.19711994,  7.70174962,  3.83966191,  3.33715343,
#         8.97952725,  9.89021778,  6.07390098,  0.5687838 ,  8.18362915,
#         2.58941032,  5.49322004,  8.52680133,  8.67577369,  3.2630922 ,
#         5.39828047,  7.90137705,  2.9679733 ,  5.09093947,  5.91019241,
#         1.01204277,  6.27819379,  8.550134  ,  5.88734632,  3.01937838,
#         1.26972074,  7.1037488 ,  3.00740451,  4.69710797,  7.845938  ,
#         3.58187628,  3.88845994,  8.20314144,  3.6628226 ,  5.51619211,
#         3.00363901,  4.02478869,  6.26382245,  3.86792512,  7.40657563,
#         7.69096318,  7.55927204,  3.86946344,  1.75352908,  2.06916093,
#         6.81164377,  4.66322136,  8.15757045,  7.95222912,  4.96323737,
#         4.89736576,  4.82370814,  3.57247724,  4.50342603,  6.83076785,
#         2.84043743,  5.78530607,  4.1881358 ,  8.11276159,  3.27992763,
#         4.66593422,  5.17635985,  7.15648344,  6.48033127,  4.47412589,
#         5.5025021 ,  6.53822567,  1.89238828,  4.74803345,  1.00948514,
#         8.05232075,  4.95568222,  4.71305692,  7.27053385,  3.35776005,
#         7.20634472,  6.22211117,  6.49795438,  5.2149748 ,  4.35749733,
#         4.24427774,  4.49370398,  3.81183592,  7.09711134,  2.5041203 ,
#         8.72140927,  5.89307292,  4.04211576,  4.1472653 ,  6.1674988 ,
#         8.69557942,  3.98412662,  3.46087787,  2.05066517,  5.28662147,
#         5.42417407,  5.81178974,  3.72441105,  5.42169338,  3.49317179,
#         1.85636553,  3.23524654,  6.83822425,  3.19791191,  5.56952895,
#         7.67890631,  5.24588256,  4.24442687,  1.94166109,  2.48768786,
#         5.58361609,  4.55426447,  2.12283491,  5.0706675 ,  5.92466916,
#         4.24783629,  6.76753548,  5.06442291,  3.44738516,  4.85958229,
#         3.68304591,  5.00252392,  5.80147505,  3.27637379,  4.46633298,
#         6.04480066,  3.19005466,  4.56569151,  7.24149859,  6.2902407 ,
#         2.23231873,  1.6132619 ,  4.23187659,  4.52359588,  6.64102922,
#         1.58769958,  2.33387069,  4.60925147,  4.40871803,  5.09165184,
#        10.30356921,  4.43446442,  6.44308933,  5.56324991,  7.22658287,
#         5.09691139,  5.18856013,  8.02628842,  4.09673451,  6.36759007,
#         4.38673764,  3.63345867,  5.92342608,  3.51335819,  7.63800087,
#         3.54426201,  6.31051993,  5.02612227,  6.59999806,  2.47259856,
#         7.20394654,  2.86547397,  4.2828514 ,  5.81196298,  5.82649435,
#         6.66703953,  5.8897665 ,  3.93093877,  9.44479522,  2.93160792,
#         7.02228061,  7.81031668,  6.91711623,  4.94332187,  7.71552182,
#         5.84230445,  3.16474565,  3.56075701,  5.99098834,  7.01339782,
#         2.83908396,  7.2091724 ,  2.82017324,  3.68918582,  7.9061588 ,
#         4.45977548,  5.95474208,  7.35669413,  3.97098188,  3.00464704,
#         6.10717008,  7.12358805,  4.41815763,  8.90721479,  5.49078589,
#         5.88494043,  3.44555448,  6.01020901,  2.99605186,  4.80190251,
#         3.45925242,  5.31366317,  4.62195029,  5.15170678,  8.74857375,
#         5.0714512 ,  3.52079404,  7.72254897,  2.20166506,  5.92325428,
#         8.01765272,  4.3711432 ,  6.11995698, 10.33929386,  5.25540797,
#         7.81686919,  6.52080417,  5.34747858,  4.44852075,  4.06833912,
#         7.44499523,  3.63371341,  2.7854307 ,  5.12605689,  2.99436629,
#         5.55253531,  3.80190556,  4.87207557,  5.93220928,  3.28236776,
#         3.83353988,  4.76866868,  3.48559753,  5.16887658,  6.77840428,
#         5.83942553,  6.22946361,  6.35351853,  6.67427215,  4.96520282,
#         6.15937857,  1.33995925,  4.64329664,  5.33386458,  5.53419084,
#         3.3255627 ,  8.81615049,  5.83124813,  0.74718303,  1.96091632,
#         4.7105413 ,  2.97974978,  5.11583775,  6.00034155,  5.06593852,
#         6.54543764,  5.22766637,  5.23508402,  5.04546156,  3.78967822,
#         7.27226237,  5.54877187,  5.52271613,  3.11727288,  4.88589768,
#         6.63031561,  4.59062805,  5.17948091,  4.55315399,  3.61639783,
#         3.30728381,  4.92086904,  7.41252006,  3.26606248,  8.00601302,
#         1.65743002,  4.33265328,  4.82399092,  3.08990538,  8.12416815,
#         9.15382642,  4.72989703,  5.19911771,  8.15887389,  5.23509676,
#         4.95228448,  4.69343666,  6.82533563,  4.01544024,  8.46166014,
#         6.66144972,  7.16979453,  2.40592607,  4.37096933,  1.24202475,
#         3.98218835,  5.89469126,  6.90578212,  6.75652874,  4.62081594,
#         5.21690997,  6.37527291,  8.69429286,  3.50605175,  3.89572336,
#         5.74629307,  5.61383801,  4.68234673,  4.38737643,  2.52746083,
#         7.83323764,  7.96187173,  5.03915819,  7.93085465,  1.84071637,
#         5.85701904,  5.1180125 ,  4.65864421,  3.91002654,  6.39395074,
#         5.3918468 ,  5.91885239,  6.56345317,  2.03605641,  1.14345167,
#         5.88899056,  2.75629328,  5.99314606,  5.08502056,  4.68245183,
#         4.30225089,  7.13858598,  3.65527982,  6.81095443,  4.94800378,
#         3.56229086, -0.4910462 ,  2.02428479,  5.72831825,  4.00141486,
#         6.1503537 ,  0.80437047,  1.97837306,  5.17000099,  4.20690206,
#         2.68229415,  8.3253    ,  8.85973402,  7.58355039,  7.70606866,
#         4.81968885,  6.46779524,  6.72240059,  4.82825402,  3.95553652,
#         9.53054306,  0.03844407,  4.52175311,  4.88813611,  3.45225685,
#         3.55721478,  5.82132878,  3.16654059,  3.52128381,  3.54728605,
#         4.25260095,  5.07617952,  4.59519352,  1.9859863 ,  6.04355727,
#         3.31227995,  4.27598043,  2.14232563,  5.52468724,  4.60656195,
#         3.99518229,  3.34677726,  6.02754352,  3.37394323,  6.78687486,
#         6.84358375,  6.02402507,  5.3962883 ,  5.51153293,  5.91098864,
#         3.87972654,  3.29452336,  4.85789988,  5.47458504,  4.39838187,
#         4.45859632,  3.52262595,  8.6864754 ,  3.37088743,  5.95052723,
#         6.60521192,  6.7962917 ,  4.2407763 ,  5.24355106,  7.73342289,
#         3.34271211,  5.01234839,  3.31583155, -0.30664056,  3.99566175,
#         1.84982566,  4.49997779,  4.43301231,  4.64163769,  4.71771681,
#         6.36800269,  6.80992959, 10.28979745,  3.05224912,  4.45968293,
#         8.8771405 ,  4.08193546,  5.72093513,  5.19984979,  6.06423678,
#         6.52561595,  6.38922936,  3.86016575,  4.57339519,  2.906208  ,
#         5.28866089,  8.47588372,  7.28368385,  1.96498984,  2.74534659,
#         6.05835121,  5.20524263,  4.41878602,  2.80242383,  5.29310899,
#         4.11490988,  1.20679744,  3.50806175,  8.9198112 ,  5.72933462,
#         1.31476309,  3.53357085,  5.91336917,  1.83216308,  3.00100355,
#         4.2425383 ,  6.0859965 ,  5.87391552,  6.96031542,  4.77975865,
#         3.47503824,  4.69773816,  7.24937642,  5.42204642,  5.73875716,
#         6.81307237,  9.22488035,  4.11593571,  7.8065617 ,  2.7200886 ,
#         1.1035131 ,  4.01786552,  2.90533652,  5.78743883,  8.00513719,
#         5.5403241 ,  6.34647248,  3.97747016,  7.05080895,  4.97760628,
#         3.50669419,  3.79715038, 11.42322154,  5.50955436,  5.47388816,
#         4.91503505,  6.33652788,  7.67650991,  7.20437087,  5.14391703,
#         4.54073571,  3.09007332,  6.03068249,  4.87524144,  1.79969489,
#         3.54562481,  7.32990242,  8.18637907,  5.88469132,  7.77248222,
#         4.36054493,  7.99674374,  5.34534222,  3.44363294,  2.91944175,
#         4.258412  ,  7.94539472,  8.65703127,  6.20772691,  3.28890555,
#         6.07372711,  6.93181141,  6.47131581,  2.43168133,  5.19906508,
#         5.8604179 ,  7.00226397,  6.09179579,  7.39400489,  6.09596332,
#         5.79052295,  5.57184938,  6.25835696,  1.49958523,  4.6976201 ,
#         6.42455233,  8.48123395,  2.76666574,  2.7290166 ,  3.80234723,
#         5.25294354,  5.69251142,  7.94143516,  2.52221282,  2.65571372,
#         7.48093393,  3.19960624,  5.22012675,  4.16691018,  1.48507467,
#         2.27919342,  5.88124277,  7.26663515,  4.9761161 ,  2.64116366,
#         4.92268912,  5.52095756,  6.52371594,  4.46425843,  5.46087402,
#         6.59364331,  4.31335387,  4.29695834,  4.76940243,  6.4488547 ,
#         7.6986112 ,  5.28642904,  5.74081441,  5.52793579,  3.57280173,
#         6.63109811,  3.74491409,  1.96349322,  5.5975704 ,  6.15270859,
#         5.90429447,  1.6490057 ,  2.46467902,  5.70365498,  4.74224751,
#         6.76358047,  3.77337827,  9.33667522,  6.080826  ,  5.9673535 ,
#         4.54441657,  6.5680577 ,  4.18292036,  7.19342871, 11.83372334,
#         7.76057652,  4.85552268,  7.71860705,  3.29844513,  3.32265357,
#         5.34980002,  1.67067917,  7.48307926,  2.47359884,  7.6433624 ,
#         4.65318305,  7.21970781,  0.58422175,  3.88342144,  7.04034819,
#         5.59893142,  4.3701596 ,  4.73540412,  6.70706549,  3.69847548,
#         2.23701245,  7.29945807,  3.56428608,  0.89534727,  5.90725799,
#         4.19177628,  2.85175243,  5.66733675,  2.20398954,  4.07264114,
#         6.63343065,  6.19161201,  6.82765541,  5.15768279,  7.02539351,
#         5.50983224,  5.27215522,  2.52992517,  3.67695607,  6.06991018,
#         5.00535021,  4.47663766,  6.10031562,  3.59727908,  7.56863867,
#         9.70847381,  4.17132151,  6.72901824,  0.17875905,  3.25074423,
#         6.21322372,  5.70324852,  5.03783818,  7.26445971,  5.61755086,
#         3.91260104, 10.7779054 ,  5.42294125,  2.89527193,  4.93343239,
#         5.77355819,  4.14138011,  4.38168892,  8.61434057,  3.52831681,
#         7.34247463,  4.09515335,  4.44306483,  4.90729635,  3.66532172,
#         5.13767095,  5.49645079,  4.34004107,  4.18142162,  5.01540827,
#         7.39497227,  2.59896235,  5.44388045,  3.16663552,  3.66573022,
#         5.92647179,  1.07194717,  6.33751221,  5.15309584,  3.91728219,
#         4.65943635,  4.59563761,  6.10312633,  5.34498994,  8.63986342,
#         4.62641439,  5.016422  ,  5.6091836 ,  5.00101992,  7.27249396,
#         4.82607347,  5.02908341,  6.83627992,  7.18372634,  0.23667198,
#         5.45034521,  5.48393319,  7.61410423,  8.14740423,  4.30363109,
#         3.94361107,  6.16180999,  3.21547724,  4.3285681 ,  3.01388942,
#         8.08833525,  5.68544733,  3.62019915,  6.08454328,  3.99541041,
#         5.33664517,  4.79129985,  9.18876367,  3.39277631,  1.02148462,
#         4.36260268,  4.09153194,  4.56899282,  6.12607873,  4.00269703,
#         3.40567553,  3.53675547,  5.09650666,  5.41553458,  2.94022481,
#         8.44642808,  2.57911122,  7.5680419 ,  4.17992939,  7.7106564 ,
#         6.1372246 ,  8.16450538,  3.2573863 ,  5.69111907,  3.38411798,
#         6.9069922 ,  7.87098567,  0.50701074,  3.7848606 ,  5.5241037 ,
#         4.31347423,  2.04186048,  8.27725904,  5.13623562,  4.86639922,
#         4.01180799,  4.81135804,  4.6157396 ,  7.13025878,  3.65068056,
#         3.39170082,  6.66672198,  7.13457896,  4.49109733,  6.31917235,
#         1.61318328,  2.73450811,  4.30745498,  4.55402412,  2.48762493,
#         6.29792693,  4.56641401,  6.44318738,  5.09928767,  6.79825513,
#         6.84165928,  4.70068335,  3.54938096,  5.35003602,  3.48538051,
#         6.90142197,  7.19743167,  7.4529509 ,  6.09182746,  4.64436152,
#         5.75153293,  5.4650118 ,  5.40125701,  5.19764855,  1.6947979 ,
#         6.52195063,  1.3986677 ,  3.37128502,  5.81808395,  7.08801371,
#         6.67560993,  0.46274111,  7.65915105,  5.26455717,  3.84876879,
#         5.64608563,  1.42935185,  6.06749901,  5.30326102,  4.21177044,
#         4.61711922,  6.15540622,  5.09395634,  4.92050747,  5.25663687,
#         4.74854745,  3.34169256,  7.3064008 ,  5.60499257,  6.16608795,
#         7.77764912,  3.71158434,  4.41311648,  6.0952391 ,  5.99268983,
#         3.98914302,  4.90628944,  5.32317942,  7.66448234,  5.51125842,
#         8.47617476,  4.8373849 ,  1.23083805,  5.3347326 ,  5.92433395,
#         7.44043456,  6.21527767,  5.70013989,  3.47162935,  3.6171195 ,
#         4.78336374,  3.67807401,  5.76577143,  9.60994761,  3.58203536])

# %%
# YOUR CHANGES HERE

# estimate the 90th percentile from the sample
p19 = np.quantile(q19, 0.9)

# %%
p19
# Out:
# np.float64(7.665685093589577)

# %% [markdown]
# ### Problem 20
#
# The data in `q20x` was generated by sampling uniformly at random between zero and two.
# The data in `q20y` was calculated as $2x + 1$ plus random noise where $x$ is the corresponding value in `q20x`.
#
# Build a linear model from `q20x` and `q20y` and set `p20` to coefficient for $x$ in that model.
# (`p20` should be close to 2, but will be slightly different due to the noise.)

# %%
# DO NOT CHANGE

q20x = [0.45542456, 0.5619655 , 1.98673764, 0.39494011, 1.03570131,
       1.07975325, 1.51760232, 0.47180573, 0.38067669, 1.84629125]

# %%
q20yy = [n * 2 for n in q20x]
q20yy
# Out:
# [0.91084912,
#  1.123931,
#  3.97347528,
#  0.78988022,
#  2.07140262,
#  2.1595065,
#  3.03520464,
#  0.94361146,
#  0.76135338,
#  3.6925825]

# %%
q20y = [0.9971621588157146, 2.5735616651097155, 4.973783648588769, 1.1067983025124097,
         1.8254939098719511, 2.998556629834516, 5.176024170423844, 1.3041595788930969,
           2.939895587626184, 4.865269147180646]

# %%
# YOUR CHANGES HERE
# q20x is your x and q20y is your y. You have to make q20x 2D
q20XX = [[x] for x in q20x]
q20XX
# Out:
# [[0.45542456],
#  [0.5619655],
#  [1.98673764],
#  [0.39494011],
#  [1.03570131],
#  [1.07975325],
#  [1.51760232],
#  [0.47180573],
#  [0.38067669],
#  [1.84629125]]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(q20XX, q20y)
# Out:
# LinearRegression()

# %%
p20 = model.coef_[0]
p20
# Out:
# np.float64(2.282723314854034)

# %% [markdown]
# ### Generative AI Usage
#
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the [generative AI policy](https://www.bu.edu/cds-faculty/culture-community/gaia-policy/).
# If you did not use any generative AI tools, simply write NONE below.

# %% [markdown]
# YOUR ANSWER HERE
